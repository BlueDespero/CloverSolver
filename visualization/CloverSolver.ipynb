# %% [markdown]
# # Setup

# %%
! git clone https://github.com/BlueDespero/CloverSolver.git
# Out:
# fatal: destination path 'CloverSolver' already exists and is not an empty directory.

# %%
import os
os.chdir("/content/CloverSolver")

# %%
! git checkout develop
# Out:
# Already on 'develop'
# Your branch is up to date with 'origin/develop'.

# %%
! git pull origin develop
# Out:
# From https://github.com/BlueDespero/CloverSolver
#  * branch            develop    -> FETCH_HEAD
# Already up to date.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install jupyter_dash
# Out:
# Requirement already satisfied: jupyter_dash in /usr/local/lib/python3.6/dist-packages (0.4.0)
# Requirement already satisfied: ansi2html in /usr/local/lib/python3.6/dist-packages (from jupyter_dash) (1.6.0)
# Requirement already satisfied: retrying in /usr/local/lib/python3.6/dist-packages (from jupyter_dash) (1.3.3)
# Requirement already satisfied: flask in /usr/local/lib/python3.6/dist-packages (from jupyter_dash) (1.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from jupyter_dash) (2.23.0)
# Requirement already satisfied: ipython in /usr/local/lib/python3.6/dist-packages (from jupyter_dash) (5.5.0)
# Requirement already satisfied: dash in /usr/local/lib/python3.6/dist-packages (from jupyter_dash) (1.19.0)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.6/dist-packages (from jupyter_dash) (4.10.1)
# Requirement already satisfied: six>=1.7.0 in /usr/local/lib/python3.6/dist-packages (from retrying->jupyter_dash) (1.15.0)
# Requirement already satisfied: Jinja2>=2.10.1 in /usr/local/lib/python3.6/dist-packages (from flask->jupyter_dash) (2.11.3)
# Requirement already satisfied: itsdangerous>=0.24 in /usr/local/lib/python3.6/dist-packages (from flask->jupyter_dash) (1.1.0)
# Requirement already satisfied: click>=5.1 in /usr/local/lib/python3.6/dist-packages (from flask->jupyter_dash) (7.1.2)
# Requirement already satisfied: Werkzeug>=0.15 in /usr/local/lib/python3.6/dist-packages (from flask->jupyter_dash) (1.0.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->jupyter_dash) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->jupyter_dash) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->jupyter_dash) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->jupyter_dash) (2020.12.5)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.6/dist-packages (from ipython->jupyter_dash) (1.0.18)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.6/dist-packages (from ipython->jupyter_dash) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.6/dist-packages (from ipython->jupyter_dash) (53.0.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.6/dist-packages (from ipython->jupyter_dash) (4.4.2)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.6/dist-packages (from ipython->jupyter_dash) (4.3.3)
# Requirement already satisfied: pygments in /usr/local/lib/python3.6/dist-packages (from ipython->jupyter_dash) (2.6.1)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.6/dist-packages (from ipython->jupyter_dash) (0.8.1)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /usr/local/lib/python3.6/dist-packages (from ipython->jupyter_dash) (4.8.0)
# Requirement already satisfied: flask-compress in /usr/local/lib/python3.6/dist-packages (from dash->jupyter_dash) (1.8.0)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from dash->jupyter_dash) (0.16.0)
# Requirement already satisfied: dash-core-components==1.15.0 in /usr/local/lib/python3.6/dist-packages (from dash->jupyter_dash) (1.15.0)
# Requirement already satisfied: dash-renderer==1.9.0 in /usr/local/lib/python3.6/dist-packages (from dash->jupyter_dash) (1.9.0)
# Requirement already satisfied: dash-table==4.11.2 in /usr/local/lib/python3.6/dist-packages (from dash->jupyter_dash) (4.11.2)
# Requirement already satisfied: plotly in /usr/local/lib/python3.6/dist-packages (from dash->jupyter_dash) (4.4.1)
# Requirement already satisfied: dash-html-components==1.1.2 in /usr/local/lib/python3.6/dist-packages (from dash->jupyter_dash) (1.1.2)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.6/dist-packages (from ipykernel->jupyter_dash) (5.3.5)
# Requirement already satisfied: tornado>=4.0 in /usr/local/lib/python3.6/dist-packages (from ipykernel->jupyter_dash) (5.1.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from Jinja2>=2.10.1->flask->jupyter_dash) (1.1.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.6/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython->jupyter_dash) (0.2.5)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.6/dist-packages (from traitlets>=4.2->ipython->jupyter_dash) (0.2.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.6/dist-packages (from pexpect; sys_platform != "win32"->ipython->jupyter_dash) (0.7.0)
# Requirement already satisfied: brotli in /usr/local/lib/python3.6/dist-packages (from flask-compress->dash->jupyter_dash) (1.0.9)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.6/dist-packages (from jupyter-client->ipykernel->jupyter_dash) (2.8.1)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.6/dist-packages (from jupyter-client->ipykernel->jupyter_dash) (22.0.2)
# Requirement already satisfied: jupyter-core>=4.6.0 in /usr/local/lib/python3.6/dist-packages (from jupyter-client->ipykernel->jupyter_dash) (4.7.1)

# %%
import numpy as np
from pathlib import Path

from utils.sudoku_transcription import sudoku_generator,print_sudoku,sudoku_matrix_representation
from utils.sudoku_transcription_model_2 import print_sudoku2,sudoku_matrix_representation2

from genetic.full_algorithms.compound_genetic_algorithm import Compound_evolutionary_algorithm, plot_CEA_solution
from genetic.full_algorithms.extended_progressive_evolutionary_algorithm import plot_EPEA_solution
from genetic.full_algorithms.progressive_evolutionary_algorithm import plot_PEA_solution


from visualization.plots import visualize_SGA

# %%
path = '/content/drive/MyDrive/Colab Notebooks/data2'
pathlist = Path(path).rglob('*.pickle')
pathlist = [path for path in pathlist]
np.random.seed(2)
grid4x4 = sudoku_generator(size=4)
coordinates4x4, transcription_matrix4x4 = sudoku_matrix_representation(grid4x4)

grid9x9 = sudoku_generator(size=9)
coordinates9x9, transcription_matrix9x9 = sudoku_matrix_representation(grid9x9)
coordinates9x9_model_2, transcription_matrix9x9_model_2 = sudoku_matrix_representation2(grid9x9)

# %% [markdown]
# # Sformułowanie problemu pełnego pokrycia zbioru

# %% [markdown]
# Dany jest zbiór $S\subseteq 2^X$. Znaleźć takie $S^*\subseteq S$, że
# $\bigcup_{s\in S^*}s=X \land\bigcap_{s\in S^*}s=\emptyset$

# %% [markdown]
# # Benchmarki

# %% [markdown]
# Problem pełnego pokrycia najczęściej nie występuje zadany wprost, jednak wiele zagadnień można do niego sprowadzić używając odpowiedniej metody transkrypcji wymagań i możliwości na pewien szczególny zbiór $S$.

# %% [markdown]
# ## Sudoku

# %% [markdown]
# **Opis:** Jest to łamigłówka, której celem jest wypełnienie diagramu 9 × 9 w taki sposób, aby w każdym wierszu, w każdej kolumnie i w każdym z dziewięciu pogrubionych kwadratów 3 × 3 (zwanych „blokami” lub „podkwadratami”) znalazło się po jednej cyfrze od 1 do 9. Sudoku ma **tylko jedno** rozwiązanie.
#
# **Metoda transkrypcji:**
# $X$ jest zbiorem wymagań:
#
#
# *   dla każdego pola (x,y): do $X$ wpisujemy wymaganie "w wierszu x i kolumnie y ma stać jakaś liczba"
# *   dla każdego wiersza i każdej liczby (x,z): do $X$ wpisujemy wymaganie "wiersz x ma zawierać liczbę z"
# *   dla każdej kolumny i każdej liczby (y,z): do $X$ wpisujemy wymaganie "kolumna y ma zawierać liczbę z"
# *   dla każdego boksu i każdej liczby (Box#i,z): do $X$ wpisujemy wymaganie "Box #i ma zawierać liczbę z"
#
# Następnie tworzymy zbiór $S$. Robimy to dwu etapowo. Najpierw tworzymy dwa zbiory:
#
# *   $P$ będzie zbiorem liczb, które są już wpisane w sudoku w notacji (współrzędna_x, współrzędna_y, liczba): $\{(x,y,z)|x,y,z\in\{1,...,9\}\land\text{W ustawieniu początkowym w wierszu x i kolumnie y stoi liczba z}\}$
# *   $R=\{(x,y,z)|x,y,z\in\{1,...,9\}\land(\exists_{z^*\in\{1,...,9\}}(x,y,z)\in P\implies z^*=z)  \}$
#
# $S=\{\{\text{spełniane wymagania przez (x,y,z)}\}|(x,y,z)\in R\}$
#
# Zbiory $S$ oraz $X$ można łatwo reprezentować jako macierz zer i jedynek:

# %% [markdown]
# ![Table of constraints.png](data:image/png;base64,...)

# %% [markdown]
# Wiersze odpowiadają zbiorom należącym do $S$. Kolumny sklejonych z sobą czterech tabelek odpowiadają wymaganiom z $X$. Puste pola to zera. Na takiej macierzy łatwo jest określić problem pełnego pokrycia. Szukamy takiego zbioru wierszy, że suma mnogościowa elementów na odpowiadających sobie pozycjach wierszy jest wierszem samych jedynek, a ich iloczyn mnogościowy jest wierszem samych jedynek. Taką macierz będziemy nazywać macierzą transkrypcji.

# %% [markdown]
# # Znane algorytmy rozwiązujące problem pełnego pokrycia

# %% [markdown]
# ## Algorytm X

# %% [markdown]
# **Idea działania:** Algorytm rekurencyjnie przeszukuje wszystkie dopuszczalne podzbiory $S$. Zwraca wszystkie zbiory $S^*$, które są rozwiązaniem lub informację o tym, że rozwiązania nie ma. W najgorszym przypadku algorytm sprawdza wszystkie kombinacje.

# %% [markdown]
# # Nasze pomysły na rozwiązanie problemu

# %% [markdown]
# ## Funkcja celu

# %% [markdown]
# Określenie funkcji celu nie jest trywialne. Intuicja podpowiada, że należy skorzystać z całej wiedzy jaką mamy o osobniku, aby poddać go ocenie. Dlatego uzależniamy ją od dwóch parametrów:
#
#
# 1.   Stopnia poradzenia sobie z problemem - ile liczb udało się wpisać
# 2.   Stopień niedopuszczalności - ile warunków zostało złamane
#
# Najczęściej stosujemy zależność liniową czyli: $2. - 1. + \text{liczba ograniczeń}$. W ten sposób wiemy, że zawsze, nie zależnie od wymiaru sudoku, minimum funkcji celu to zero.
#
# Testowaliśmy również inne zależności:
# - kwadratową
#
# Pomysł:
# - parametryzowane

# %% [markdown]
# **Analiza złożoności problemu:**
#
# Złożoność problemu zależy od sposbu podejścia. Jeżeli będziemy przeszukiwali całą przestreń poszukiwań problem rysuje się następująco:
#
#     Sudoku 4x4
#     Rozmiar przestrzeni poszukiwań: ~10^15
#     Liczba minimów lokalnych: ~10^4
#
#     Sudoku 9x9
#     Rozmiar przestrzeni poszukiwań: ~10^161
#     Liczba minimów lokalnych: niemożliwe do sprawdzenia w sensownym czasie
#
# Jeżeli za przestrzeń poszukiwań weźmiemy tylko osobniki dopuszczalne, wtedy proporcja rysuje się następująco:
#
#     Sudoku 4x4
#     Rozmiar przestrzeni poszukiwań: ~10^6
#     Liczba minimów lokalnych: ~10^4
#
#     Sudoku 9x9
#     Rozmiar przestrzeni poszukiwań: ~10^50
#     Liczba minimów lokalnych: niemożliwe do sprawdzenia w sensownym czasie
#
# **Wnioski:**
#
# Pierwsze podejście zmusza do błądzenia po olbrzymiej przestrzeni poszukiwań, gdy drugie bardzo zawęża ten obszar. Nie można jednak na tej podstawie powiedzieć, które z nich jest lepsze. Możemy wyobrazić sobie przypadek, w którym pomimo dużego obszaru poszukiwań prawdopodobieństwo, że osobnik początkowy znajdzie się w miejscu, z którego dojdzie do minimum globalnego, jest znacznie większe niż w przypadku obcięcia przestrzeni do tej spełniającej warunki zadania. Innym minusem poruszania się po dopuszczalnej przestrzeni poszukiwań, jest kosztowne badanie jej. Podsumowując, nie jest jednoznaczne, która z metod sprawdzi się lepiej, dlatego przetestujemy obydwie.

# %% [markdown]
# ## Random sampling

# %% [markdown]
# ![Random_search_1rep.png](data:image/png;base64,...)

# %%
# Przedstawienie efektywności algorytmu - analiza wielu wykonań

# %% [markdown]
# ![Random_search_1000reps.png](data:image/png;base64,...)

# %% [markdown]
# ## Simulated annealing

# %%
# Przedstawienie efektywności algorytmu - analiza wielu wykonań

# %% [markdown]
# ![Simulated_annealing_1000reps.png](data:image/png;base64,...)

# %% [markdown]
# ## Algorytmy działające na pełnej przestrzeni poszukiwań

# %% [markdown]
# ### SGA
# Nasza implementacja SGA to szkielet algorytmu ewolcyjnego, do którego możemy łatwo dodawać operatory i parametry algorytmu ewolucyjnego - wszystko jako argumenty wywołania funkcji SGA.
#
# Pozwala nam to na szybkie testowanie świeżo napisanych operatorów, a także sprawdzanie wszystkich możliwych kombinacji operatorów i parametrów.
#
# Argumenty możliwe do ustawiania w ten sposób to:
# *   liczba iteracji
# *   liczba dzieci
# *   wielkość populacji
# *   mutation rate
#
# Typy dostępnych operatorów (podpunkty pod typami to nasze implementacje):
#
# *   Mutacji
#   *   shuffle_column_mutation - permutacja sudoku w obrębie 1 kolumny
#   *   shuffle_row_mutation - permutacja sudoku w obrębie 1 wiersza
#   *   shuffle_box_mutation - permutacja sudoku w obrębie 1 sekcji
#   *   reverse_bit_mutation - rozwiązanie jest implementowane jako wektor bitów. Ta mutacja obwarca jeden z nich na przeciwny
# *   Crossover
#   *   exchange_two_rows_crossover - tworzenie dzieci poprzez wymianę wiersza między rodzicami
#   *   exchange_two_columns_crossover - tworzenie dzieci poprzez wymianę kolumny między rodzicami
#   *   exchange_two_boxes_crossover - tworzenie dzieci poprzez wymianę sekcji między rodzicami
#   *   single_point_crossover - wymiana chromosomu od jednego, losowego miejsca.
#   *   double_point_crossover - wymiana chromosomu między dwoma, losowymi miejscami
# *   Tworzenie kolejnej populacji
#   * lambda_plus_mu
#   * lambda_coma_mu
#
# Jako argument można przekazać również:
# *   Funkcję celu
#   *   linear_fitness - ocena rozwiązania to suma pogwałceń ograniczeń sudoku.
#   *   quadratic_fitness - ocena rozwiązania to suma kwadratów pogwałceń ograniczeń sudoku. Sprawia to, że wielokrotne pogwałcenie jednego ograniczenia jest bardziej karane.
# *   Początkowe wypełnienie sudoku
#   * Można je generować np. za pomocą narzędzia generate_test_inputs.py

# %%
visualize_SGA(pathlist)

# %% [markdown]
# ## Algorytmy działające na dopuszczalnej przestrzeni poszukiwań

# %% [markdown]
# ### Progressive evolutionary algorithm
# pierwsze podejście quasi genetyczne

# %% [markdown]
# **Opis działania:**
# populacja początkowa zaczyna z tylko jedną ustawioną liczbą, wobec czego każdy osobnik jest dopuszczalny. Następnie w pętli, aż do osiągnięcia pełnego sudoku lub limitu iteracji wykonuje dwie operacje:
#
# - Jeśli aktualny osobnik jest dopuszczalny, dokłada nową losowo wybraną liczbę w losowo wybranym polu.
#
# - W przeciwnym przypadku ostatnia liczba została dołożona źle. Algorytm dokonuje mutacji osobnika polegającej na usunięciu złego elementu i dołożeniu jakiegoś innego.

# %%
plot_PEA_solution(transcription_matrix9x9, size_of_population=10**5,max_iter=10**4,tqdm_mode=True)

# %% [markdown]
# Sudoku $4\times 4$ znalezione rozwiązanie
#
# ![PEA_4x4_founded.png](data:image/png;base64,...)

# %% [markdown]
# Sudoku $4\times 4$ nie znalezione rozwiązanie
#
# ![PEA_4x4_not_founded.png](data:image/png;base64,...)

# %%
# Przedstawienie efektywności algorytmu - analiza wielu wykonań

# %% [markdown]
# **Analiza:** skuteczność algorytmu zależy od tego czy pewnemu osobnikowi uda się losować tylko liczby, które ostatecznie powinny znaleźć się na danych polach oraz od tego czy uda się zakończyć proces wypełniania nim upłynie dostępna liczba iteracji. Innymi słowy, pierwszy warunek oznacza, że pewien osobnik nigdy nie ustawi liczby potencjalnie dobrej (pasującej do poprzednich), ale innej niż docelowa.
#
# >Plusem takiego podejścia jest fakt, że pomimo iż funkcja celu nie wymusza otrzymywania poprawnych osobników, to tylko takie są rozważane.
#
# > Minusem jest to, że wystarczy raz trafić na liczbę pasującą do poprzednich, ale inną niż właściwa, aby dany osobnik "ugrzązł" i jedynie spowalniał algorytm. Przykład takiego osobnika poniżej:
#
# ![Sudoku_path.png](data:image/png;base64,...)
#
# > Algorytm wstawił jedynkę na puste pole (obrazek 3.). Mimo iż nie kłuci się ona z żadną inną liczbą, to sudoku w takiej konfiguracji jest już niewykonalne. Taki rozwój osobnika będzie dalej nazywany złą drogą, dojściem do martwego punktu.
#
# **Uwagi:**
# ta wersja algorytmu jest w stanie rozwiązywać najprostrze benchmarki

# %% [markdown]
# ### Extended progressive evolutionary algorithm

# %% [markdown]
# **Opis:** algorytm bazuje na swojej wersji podstawowej. Został jednak rozszeżony o parametr wstecznego horyzontu czasowego oraz o operator pozwalający na radzenie sobie z przypadkiem zejścia osobnika na złą drogę.
#
#
# *   Wsteczny choryzont czasowy - parametr indywidualny dla każdego osobnika, pamięta informację o tym jak odległa była ostatnia mutacja na poprawnego osobnika
# *   "krzyżowanie" - gdy liczba mutacji na gorszego osobnika osobnika w danym stadium przekroczy oczekiwany czas oczekiwania na sukces półtorej razy, osobnik przejmuje 3/4 chromosomu od wylosowanego innego chromosomu. Dobór drugiego rodzica następuje metodą ruletki.
#
# **Analiza:** metoda zastosowana w tym podejściu rozwiązuje problem dojścia do martwego punktu, dzięki czemu jest o wiele skuteczniejsza niż poprzednia. Wciąż jednak nie jest w stanie poradzić sobie z trudniejszymi sudoku.
#
#
#
# > Plusem jest skuteczne wykorzystanie nagromadzonej wiedzy o osobnikach poprzedzających.
#
#
# > Minusem jest wciąż niesatysfakcjonująca efektywność.
#
# **Uwagi:** to podejście wciąż nie używa żadnej informacji o problemie. Osobniki wciąż działają po omacku, nie zakładając zależności zmiennych.

# %% [markdown]
# **Szczegółowa analiza:**
#
# Napotkaliśmy na problem określenia czy osobnik, który pewien czas błądzi wokół jakiegoś rozwiązania doszedł do minimum lokalnego, czy po prostu wciąż losuje osobniki niedopuszczalne. Zakładamy, że chcielibyśmy mieć 90% prawdopodobieństwo, że jeśli nasz algorytm zdecyduje się na operację krzyżowania to będzie to słuszne. Patrząc na to z drugiej strony: liczba iteracji określająca czas, przez który osobnik ma przeszukiwać swoje otoczenie, może wynieść maksymalnie tyle, aby średnia szansa na to, że nie znalazł lepszego rozwiązania, pomimo istnienia takiego, wyniosła wyniosła mniej niż 10%.
#
# Zauważmy, że prawdopodobieństwo satysfakcjonującej mutacji zależne jest od kilku czynników. Po pierwsze od rozmiaru planszy do sudoku. Oznaczmy ją przez $n$, standardowo jest równa 9. Dalej od aktualnego stadium, czyli liczby już ułożonych liczb - oznaczmy przez $k\in\{1,2,...,n^2\}$. Ostatecznie również od liczby liczb początkowych - oznaczmy przez $l$.
#
# Ze znalezionych danych statystycznych dla sudoku $9$x$9$ liczbę $l$ można szacować w zależności od poziomu trudności:
# - 35-45 łatwe
# - ~25 trudne
# - 17 najtrudniejsze (zarazem najmniejsza liczba jaką można uzyskać)
# Dla ułatwienia dalszych obliczeń załóżmy, że $l=30$ oraz załóżmy, że proporcjonalność liczby pól początkowych do pól w ogóle jest stała. Zatem w ogólności:
# $$\frac{l}{n^2}\approx\frac{30}{81}\approx\frac{3}{8}\implies l\approx\frac{3}{8}n^2$$
#
# Niech $X_{n,k}$ oznacza zmienną losową odpowiadającą czasowi przeszukiwania lokalnego aż do znalezienia lepszego osobnika dla sudoku o wymiarach $n\times n$ i po wpisaniu $k-1$ liczb. $X_k\sim \text{G}(p)$. Aby oszacować czas $t$ potrzebny na uzyskanie $90\%$ pewności, że jeśli istnieje lokalnie lepszy osobnik, to uda się go znaleźć można wyznaczyć rozwiązując nierówność:
# $$\sum_{i=1}^t P(X_{n,k}=i)\geq 90\%$$
# $$t\geq\frac{1}{log_{10}(\frac{1}{1-p})}$$
#
# Problemem pozostaje wyznaczenie $p$. Jest ono pewną funkcją $n$ i $k$, której wyznaczenie wprost okazało się zbyt skomplikowane. Rozwiązaniem okazała się metoda polegająca na zbadaniu na wielu przykładach rozkładu zmiennej $X_{n,k}$. Aproksymacja w ten sposób rozkładu okazała się być bardzo dobra - szybko się stabilizuje.

# %%
# Statystyczne wyznaczenie rozkładu

# %% [markdown]
# Rozkład prawdopodobieństwa sukcesu w zależności od tego, którą liczbę skolei wpisujemy.
#
# ![Probability_of_success_distribution.png](data:image/png;base64,...)

# %% [markdown]
# ![Distribution_of_fails_during_filling_a_grid.png](data:image/png;base64,...)

# %%
# Przedstawienie efektywności algorytmu - analiza jednego wykonania
plot_EPEA_solution(transcription_matrix4x4, size_of_population=10**4,size_of_sudoku=4,tqdm_mode=True)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1289.0), HTML(value='')))
# Fitness value
# Best: 0
# Mean: 32.0123
# Worst: 64
#
# Number of filled squares
# Max: 16
# Mean: 9.4091
# Min: 0

# %% [markdown]
# Sudoku $4\times 4$
#
#
#
# ![EPEA_4x4.png](data:image/png;base64,...)

# %%
plot_EPEA_solution(transcription_matrix9x9_model_2,max_iter=100, size_of_population=10**4,size_of_sudoku=9,tqdm_mode=True)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# Fitness value
# Best: 31
# Mean: 88.2152
# Worst: 156
#
# Number of filled squares
# Max: 34
# Mean: 20.1459
# Min: 2

# %% [markdown]
# Sudoku $9\times 9$

# %%
# Przedstawienie efektywności algorytmu - analiza wielu wykonań

# %% [markdown]
# ###  Compound evolutionary algorytm

# %% [markdown]
# **Idea:** Analiza skuteczności poprzedniego podejścia skłoniła nas do głębszego wniknięcia w strukturę problemu. W tym celu wygenerowaliśmy wszystkie możliwe osobniki jakie nasz algorytm mógłby utworzyć, pogrupowaliśmy je ze względu na:
# - liczbę wpisanych liczb do widoku
# - bycie osobniki dopuszczalnym, bycie osobnikiem niedopuszczalnym, bycie lokalnym minimum
# Wykresy poniżej przedstawiają zebrane dane:

# %% [markdown]
# ![Probability_of_improvement.png](data:image/png;base64,...)

# %% [markdown]
# ![Fraction_of_acceptable_solutions_leading_to_global_optima.png](data:image/png;base64,...)

# %% [markdown]
# Jak widać z pierwszego wykresu największy problem EPEA będzie miał w części końcowej. Skolei stosunkowo szybko powinien osiągać dość dobre wyniki - jak faktycznie się dzieje. Stąd pomysł na kolejny algorytm. Zastosowaliśmy strategię polegającą na przejściu na algorytm X, gdy osobniki osiągną satysfakcjonujące rezultaty.

# %%
plot_CEA_solution(transcription_matrix4x4,size_of_population=10**4,size_of_sudoku=4,tqdm_mode=True)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1285.0), HTML(value='')))
# Fitness value
# Best: 12.0
# Mean: 36.0796
# Worst: 60.0
#
# Number of filled squares
# Max: 13.0
# Mean: 8.1363
# Min: 1.0

# %%
plot_CEA_solution(transcription_matrix9x9_model_2,size_of_population=10**4,size_of_sudoku=9,tqdm_mode=True,
                  P=3,transforming_factor=0.4)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=16738.0), HTML(value='')))
# Fitness value
# Best: 36.0
# Mean: 95.7315
# Worst: 156.0
#
# Number of filled squares
# Max: 32.0
# Mean: 18.1355
# Min: 2.0

# %% [markdown]
# Sudoku 9x9:
#
# ![CEA_4x4.png](data:image/png;base64,...)

# %% [markdown]
# **Analiza:**
# Algorytm Rozwiązuje sudoku 9x9 w około pół minuty.

# %% [markdown]
# ### Wnioski końcowe

# %% [markdown]
# Algorytmy tej grupy dają pozytywne rezultaty, jednak czas rozwiązania sudoku niekiedy bywa dość długi, zbyt długi aby można było tu mówić o jakimś przełomie względem algorytmu deterministycznego.

# %% [markdown]
# ## Pomysły na dalszy rozwój:
#
#
# *   Rozszerzenie do PEA/EPEA o osobniki trochę niedopuszczalne. Jest tylko jedna droga ewolucyjna, która prowadzi od napisania pierwszej liczby do ułożenia całego sudoku tak, że każdą cyfrę po drodze wpisujemy dobrze. Jest natomiast wiele dróg dojścia do sukcesu jeżeli algorytm będzie mógł czasem zejść z właściwej ścieżki.
#
# *   Zupełnie inne podejście. Skorzystać z wiedzy o tym jak wygląda macierz transkrypcji i losować osobników jedynie spośród osobników dopuszczalnych - problem z operatorami krzyżowania
#
# *   Stworzyć algorytm pozwalający badać populację pod kątem tego jak rozległą część przestrzeni poszukiwań ona obejmuje -> metoda porównywania algorytmów
#
# *   Dopisać więcej benchmarków niż tylko sudoku
#
# *   Zastosować strategię rozwiązywania problemu np. w 80%, a resztę zostawić algorytmowi deterministycznemu -> powinno rozwiązać problem powolnego przeszukiwania minimów lokalnych
